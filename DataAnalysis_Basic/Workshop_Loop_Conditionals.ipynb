# %%
# Escoja una opcion y reciba un comentario basado en los comentarios de muchos otros usuarios:
de= input ('escoja una opcion: a) antioquia. b) quindio. c) cundinamarca. d) valle. [a/b/c/d]?:').lower()
while de=='a':
    city= input ('escoja una opcion: a) medellin. b) envigado. c) bello. d) yarumal [a/b/c/d]?:').lower()
    if city == 'a':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == 'a':
            food= input ('escoja una opcion: a) frijolada. b) arepas. c) mazamorra. d) carneMolida. [a/b/c/d]?:').lower()
            print("Buena opcion, ese es nuestro plato mas recomendado")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) pavoReal. b) mico. c) golondrina. d) apiario. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) lanzadores. b) botero. c) elPeñol. d) rioNegro. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta ese lugar")
        if opcion == 'd':
            music=input('escoja una opcion: a) juanes. b) kraken. c) medalloBello. d) AmoAMedellin. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")
    elif city == 'b':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == 'a':
            food= input ('escoja una opcion: a) pescado. b) pandebono. c) mazorcada. d) pandeyuca. [a/b/c/d]?:').lower()
            print("Ese es mi plato preferido, de tomar que desea?")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) pato. b) mono. c) avestruz. d) avispas. [a/b/c/d]?:').lower()
            print("Le gustan esos animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) casaPiedra. b) zoologico. c) parapente. d) mercadoPulgas. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta ese lugar")
        if opcion == 'd':
            music=input('escoja una opcion: a) salsa. b) rockEspañol. c) carrilera. d) bolero. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")
    elif city == 'c':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == 'a':
            food= input ('escoja una opcion: a) maizPintado. b) huevos. c) obleas. d) pastas. [a/b/c/d]?:').lower()
            print("Ese es nuestro plato del dia")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) perico. b) nutria. c) halcon. d) mariposa. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) callePiedra. b) plazaCentral. c) mercadoCampesino. d) rio. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta la Plaza de Botero")
        if opcion == 'd':
            music=input('escoja una opcion: a) milonga. b) champeta. c) regue. d) merengue. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")
    elif city == 'd':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == 'a':
            food= input ('escoja una opcion: a) caldo. b) chicharron. c) chorizo. d) melcocha. [a/b/c/d]?:').lower()
            print("Ese es el plato de la casa")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) faisan. b) nasuella. c) venado. d) zorrillo. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) casaCultura. b) biblioteca. c) laguna. d) parque. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta la Plaza de Botero")
        if opcion == 'd':
            music=input('escoja una opcion: a) bachata. b) tango. c) mariachi. d) despecho. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")

while de=='b':
    city= input ('escoja una opcion: a) armenia. b) salento. c) calarca. d) pijao [a/b/c/d]?:').lower()
    if city == 'a':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == 'a':
            food= input ('escoja una opcion: a) perroCaliente. b) Patacones. c) yuca. d) lentejas. [a/b/c/d]?:').lower()
            print("Como desee")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) faisan. b) nasuella. c) venado. d) zorrillo. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) casaCultura. b) biblioteca. c) laguna. d) parque. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta la Plaza de Botero")
        if opcion == 'd':
            music=input('escoja una opcion: a) bachata. b) tango. c) mariachi. d) despecho. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")
    elif city == 'b':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == 'a':
            food= input ('escoja una opcion: a) garbanzos. b) aguadepanela. c) peto. d) carneAsada. [a/b/c/d]?:').lower()
            print("Quedara satisfecho")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) petirojo. b) tapir. c) erizo. d) perroMonte. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) casaCultura. b) biblioteca. c) laguna. d) parque. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta la Plaza de Botero")
        if opcion == 'd':
            music=input('escoja una opcion: a) bachata. b) tango. c) mariachi. d) despecho. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")
    elif city == 'c':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == 'a':
            food= input ('escoja una opcion: a) lasagna. b) camarones. c) arrozConCoco. d) carneBisteq. [a/b/c/d]?:').lower()
            print("El favorito de la semana")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) colibri. b) grillo. c) langosta. d) saltamontes. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) casaCultura. b) biblioteca. c) laguna. d) parque. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta la Plaza de Botero")
        if opcion == 'd':
            music=input('escoja una opcion: a) bachata. b) tango. c) mariachi. d) despecho. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")
    elif city == 'd':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == 'a':
            food= input ('escoja una opcion: a) pechuga. b) sancocho. c) arrozVerduras. d) purePapas. [a/b/c/d]?:').lower()
            print("La salsa es recomendada")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) mosca. b) mosquitos. c) tarantula. d) micoNocturno. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) casaCultura. b) biblioteca. c) laguna. d) parque. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta la Plaza de Botero")
        if opcion == 'd':
            music=input('escoja una opcion: a) bachata. b) tango. c) mariachi. d) despecho. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")
        
while de=='c':
    city= input ('escoja una opcion: a) bogota. b) sopo. c) zipa. d)chia. [a/b/c/d]?:').lower()
    if city == 'a':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == "a":
            food= input ('escoja una opcion: a) crepes. b) arrozAtollado. c) sopaPlatano. d) quesadillas. [a/b/c/d]?:').lower()
            print("Para chuparse los dedos")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) polilla. b) cerdo. c) vaca. d) caballo. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) museoOro. b) bibliotecaLuisAngel. c) candelaria. d) parqueNacional. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta la Plaza de Botero")
        if opcion == 'd':
            music=input('escoja una opcion: a) bachata. b) tango. c) mariachi. d) rockAlParque. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")
    
    elif city == 'b':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == "a":
            food= input ('escoja una opcion: a) milo. b) pastasChampiñones. c) gallinaHorno. d) chuleta. [a/b/c/d]?:').lower()
            print("Quedara bien lleno")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) osoHormiguero. b) tigrillo. c) ciervo. d) zorroMonte. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) calleCentral. b) parqueSopo. c) laguna. d) Alpina. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta la Plaza de Botero")
        if opcion == 'd':
            music=input('escoja una opcion: a) bachata. b) tango. c) mariachi. d) despecho. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")
    elif city == 'c':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == "a":
            food= input ('escoja una opcion: a) Pollobroster. b) hamburguesa. c) pescadoFrito. d) caldoPapa. [a/b/c/d]?:').lower()
            print("Acompañelo con una limonada")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) escarabajo. b) nutria. c) chiguiro. d) rata. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) casaCultural. b) ciclistas. c) catedralSal. d) parqueCompartir. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta la Plaza de Botero")
        if opcion == 'd':
            music=input('escoja una opcion: a) bachata. b) tango. c) mariachi. d) despecho. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")
    elif city == 'd':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == "a":
            food= input ('escoja una opcion: a) Mondongo. b) verdurasGuisadas. c) tajadasConHuevo. d) arrozAtun. [a/b/c/d]?:').lower()
            print("Delicioso, desea un tinto?")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) raton. b) osilla. c) conejo. d) liebre. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) jardinBotanico. b) plazaFlores. c) fuenteLasLuces. d) festivalVerano. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta la Plaza de Botero")
        if opcion == 'd':
            music=input('escoja una opcion: a) bachata. b) tango. c) mariachi. d) despecho. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")

while de=='d':
    city= input ('escoja una opcion: a) cali. b) palmira. c) buga. d)tulua. [a/b/c/d]?:').lower()
    if city == 'a':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == "a":
            food= input ('escoja una opcion: a) CremaZanahoria. b) berenjenaGuisada. c) esparragosHorneados. d) SopaAuyama. [a/b/c/d]?:').lower()
            print("Ese viene en porcion grande y mediana, cual desea?")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) azulejo. b) toche. c) pechiamarilli. d) turpial. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) torreLaPaz. b) mirador. c) cineColombia. d) ciclovia. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta la Plaza de Botero")
        if opcion == 'd':
            music=input('escoja una opcion: a) bachata. b) tango. c) mariachi. d) despecho. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")
    elif city == 'b':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == "a":
            food= input ('escoja una opcion: a) lechona. b) arrozFideos. c) caldoCostilla. d) CarneOreada. [a/b/c/d]?:').lower()
            print("Viene con postre de arandanos")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) mirla. b) cuervo. c) guacamaya. d) pavo. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) caminataRural. b) museoMusical. c) museoCulturaIndigena. d) velodromo. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta la Plaza de Botero")
        if opcion == 'd':
            music=input('escoja una opcion: a) bachata. b) tango. c) mariachi. d) despecho. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")
    elif city == 'c':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == "a":
            food= input ('escoja una opcion: a) enyucado. b) ñameEnSalsa. c) papaChorreada. d) huevosRevueltos. [a/b/c/d]?:').lower()
            print("Disculpenos, se nos agoto el plato, le podemos sugerir una alternativa")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) mula. b) burro. c) llama. d) boa. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) museoHistorico. b) artesanias. c) cafecillo. d) teatro. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta la Plaza de Botero")
        if opcion == 'd':
            music=input('escoja una opcion: a) bachata. b) tango. c) mariachi. d) despecho. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")
    elif city == 'd':
        opcion=input('escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:').lower()
        if opcion == "a":
            food= input ('escoja una opcion: a) sopaEspinacas. b) mute. c) pastaAtun. d) arrozConLeche. [a/b/c/d]?:').lower()
            print("Lo desea bien caliente?")
        if opcion == 'b':
            fauna=input('escoja una opcion: a) cobra. b) anaconda. c) cascabel. d) lombriz. [a/b/c/d]?:').lower()
            print("Le gustan los animales?")
        if opcion == 'c':
            history=input('escoja una opcion: a) calleVieja. b) libreriaNacional. c) lagunilla. d) bar. [a/b/c/d]?:').lower()
            print("A mi tambien me encanta la Plaza de Botero")
        if opcion == 'd':
            music=input('escoja una opcion: a) bachata. b) tango. c) mariachi. d) despecho. [a/b/c/d]?:').lower()
            print("Buena musica, la disfruto mucho")
# Out:
# escoja una opcion: a) antioquia. b) quindio. c) cundinamarca. d) valle. [a/b/c/d]?:a
# escoja una opcion: a) medellin. b) envigado. c) bello. d) yarumal [a/b/c/d]?:a
# escoja una opcion: a) food. b) fauna. c) history. d) music. [a/b/c/d]?:a
# escoja una opcion: a) frijolada. b) arepas. c) mazamorra. d) carneMolida. [a/b/c/d]?:a
# Buena opcion, ese es nuestro plato mas recomendado
